# %% [markdown]
# # 상승장? 하락장?
#
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
# >>변동폭 : 최고가와 최저가의 차이
# 시가 : 시작가
# 상승장 : 시가 + 변동폭이 최고가보다 높은 경우
#
# |Key Name|Description|
# |------|---|
# |opeing_price|최근 24시간 내 시작 거래금액|
# |closing_price|최근 24시간 내 마지막 거래금액|
# |min_price|최근 24시간 내 최저 거래금액|
# |max_price|최근 24시간 내 최고 거래금액|

# %%
import requests

url = "https://api.bithumb.com/public/ticker/btc"
data = requests.get(url).json()['data']
print(data)
# Out:
# {'opening_price': '13484000', 'closing_price': '12340000', 'min_price': '11879000', 'max_price': '13533000', 'average_price': '12648500.7338', 'units_traded': '17350.66333232', 'volume_1day': '17350.66333232', 'volume_7day': '90557.94761718', 'buy_price': '12316000', 'sell_price': '12340000', '24H_fluctate': '-1144000', '24H_fluctate_rate': '-8.48', 'date': '1563178582580'}

# %%
maxprice = int(data['max_price'])
minprice = int(data['min_price'])
gap = maxprice - minprice
openingprice = int(data['opening_price'])


if openingprice + gap > maxprice:
    print('상승장')
else:
    print('하락장')
# Out:
# 상승장

# %% [markdown]
# # 모음 제거하기
#
# > 다음 문장의 모음을 제거하여 출력하세요.
#
# ```
# 예시 입력)
# "Life is too short, you need python"
# 예시 출력)
# Lf s t shrt, y nd pythn
# ```

# %%
my_str = "Life is too short, you need python"

# %%
# 아래에 코드를 작성하세요.
a = ['a', 'e', 'i', 'o', 'u']
for i in a:
    my_str=my_str.replace(i, '')
print(my_str)
